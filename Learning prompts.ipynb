# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# python-dotenv could not parse statement starting at line 2
# True

# %% [markdown]
# # Example 1

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model("openai/gpt-oss-120b", model_provider="groq")

# %%
# Prompt template

prompt_template = """Translate the given text in to the given language: 
Text: {text}
Lang: {lang}
"""

# %%
prompt = prompt_template.format(text = "Who are you?", lang="hindi")
print(prompt)
# Out:
# Translate the given text in to the given language:
# Text: Who are you?
# Lang: hindi

# %%
# A simple model call

response =  model.invoke(prompt)
response
# Out:
# AIMessage(content='**Hindi:**\u202fआप कौन हैं?', additional_kwargs={'reasoning_content': 'The user wants translation: "Who are you?" into Hindi. Provide translation. Should be "आप कौन हैं?" Possibly "तुम कौन हो?" depending on formal. Use formal. Provide translation.'}, response_metadata={'token_usage': {'completion_tokens': 58, 'prompt_tokens': 92, 'total_tokens': 150, 'completion_time': 0.116066, 'prompt_time': 0.003314332, 'queue_time': 0.045761678, 'total_time': 0.119380332}, 'model_name': 'openai/gpt-oss-120b', 'system_fingerprint': 'fp_213abb2467', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None}, id='run--3153502c-cd44-4270-9e15-a807cc5a61ae-0', usage_metadata={'input_tokens': 92, 'output_tokens': 58, 'total_tokens': 150})

# %%
print(response.content)
# Out:
# **Hindi:** आप कौन हैं?

# %% [markdown]
# EXERCISE 2

# %%
prompt_2 = """Do the following function on the following number and write no extra text omly the final answer :
 num : {num}
 func : {func}
 """

# %%
prompt = prompt_2.format(num = "5", func = "factorial")
print(prompt)
# Out:
# Do the following function on the following number and write no extra text omly the final answer :
#  num : 5
#  func : factorial

# %%
model.invoke(prompt).content
# Out:
# '120'

# %% [markdown]
# # Exercise: A RAG Prompt
#
# https://smith.langchain.com/hub/rlm/rag-prompt

# %%
prompt_template = """You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.
Question: {question} 
Context: {context} 
Answer:"""

# %%
prompt = prompt_template.format(
    context = "Ajit lives in Greater Noida", 
    question="In which country does Ajit live in?"
)

from langchain.chat_models import init_chat_model
model = init_chat_model("openai/gpt-oss-120b", model_provider="groq")

response = model.invoke(prompt)
print(response.content)
# Out:
# Ajit lives in Greater Noida, which is located in India.

# %%
prompt = prompt_template.format(
    context = "Gregory house from house md is a wicked genius", 
    question="what is the personality of dr house like?"
)


response = model.invoke(prompt)
print(response.content)
# Out:
# Dr. Gregory House is a brilliant, often‑called “wicked,” medical genius. He’s notoriously cynical, sarcastic, and abrasive, frequently flouting rules and social niceties. Despite his rough exterior, he’s deeply driven by solving complex cases.

# %%
prompt = prompt_template.format(
    context = "On September 16, 2023, a group of Shiv Nadar IoE students travelled to the Aravalli Biodiversity Park for the field survey as our project in Environmental Studies (CCC704). When we arrived at the Aravalli Biodiversity Park's main entrance we moved along a curvy path that was flanked on both sides by greenery as we entered the park. The group had gathered in an open area after covering some distance where the instructor briefed us about the park. We spotted many different plants, trees, and even a pair of peahens throughout this walk. ", 
    question="where did the students go and what did they see tell in under 1line?"
)


response = model.invoke(prompt)
print(response.content)
# Out:
# They visited the Aravalli Biodiversity Park and saw a variety of plants, trees and a pair of peahens.

# %%
SNUCONtext = """In the rat race we call life, we as students have been blessed to be part of a prestigious institution like Shiv Nadar Institute of Eminence. Being part of such a renowned institution comes with its perks in terms of the quality of education and the availability of resources we as students have at our disposal. However, despite these perks, we face several challenges, including the course enrollment process. The enrollment process has been built meticulously by the administration based on past experience and has even made certain adaptations this time around to help alleviate some of the stress that comes with this process; however, some flaws remain.

As a second year student at SNU, this isn’t the first time I have dealt with the enrollment process, and I know this won’t be the last, but this is the first time a lot of us have dealt with the full brunt of the problems within the system.

Despite the admin’s best efforts to make the system better, major flaws remain. These flaws, in broad strokes, can be explained in a few key facts: lack of CCC options, lack of CCC seats, lack of UWE options, lack of UWE seats, lack of ability to pick either one because of clashing timings, and various technical issues. This lack of choice means that the students are forced to pick up online Swayam courses to meet academic requirements. The root issue that presents itself here is the overall low teaching staff to student ratio due to constant increase in student population every year. The problem cannot be blamed on the professors alone; the infrastructure is also considerably lacking, as professors are also limited in the number of students they can accommodate because the size of the classrooms act as a limiting factor.

The following are grievances that I’ve heard from parents and students regarding these issues:-

“1685 seats for 2389 students who need to take CCCs. So over 700 students can’t access courses that they need to take to get a degree”
“I believe the college should gauge how much there is a demand for each course and then have seats accordingly”
“I had added one UWE and 2 CCC’s to my course wish list just for backu[p]. The site stopped responding [and I] had to reload, then tried enrolling showed a red box saying enrollment couldn’t be completed, site stopped responding […] and [I] ended up getting no course even though I was all prepared for this registration from 2:30 [pm].”
“ why are students being forced to give up quality of education by taking an online course”
“ We’re paying for this total number of credits in these 4 yrs [years] however we’re needed to do and then again to complete those credits that we already paid for we’re having to take swayam courses. Like if you’re going to do this then just don’t take 6K per credit for tuition[.] You’re not teaching us for those credits anyways.” (The ₹6,000 per credit for tuition, as claimed by the student here, refers to the tuition system for the summer semester. However, for the monsoon and spring semesters, the cost per credit varies depending on the degree the student is pursuing, as fees differ for each degree, and the maximum number of credits a student can take is 25 per semester, regardless of the degree chosen. Certain degrees have fees higher than ₹6,000 per credit, while others may be lower.)
“I just have an issue with the lack I of CCCs and a further lack of seats in the CCCs offered”
“ I wanted the news writing CCC and the prof opened more seats at 3[pm] but because enrollment opened 10 mins late by the time we could enrol seats were gone and when I tried adding others[other CCC’s] same[issue happened].”
“ There’s no UWEs most of us can take despite being in third year, and most of us don’t even have a single major elective. They literally don’t have enough seats to make sure all of us get an elective at all, let alone something that interests us” (third year B.Tech CSE major)
“ the untold truth: You can’t do a minor” “[it is] indeed a marketing strategy”
“Yes [I] did face similar issues to this thing of not getting enrolled in [a] single ccc’s but also that how the social sciences and humanities department have really very less CCCs based on their area of interest and themes like a to of them is either science or English. This is something I really think should be given a thought about.”
“ If we were to take admission after knowing what we know now I think more than 50% of us would not take admission in SNU. I am looking to move my kid to another university if there’s a lateral entry option.”
In response to the freshers raising concerns about the enrollment process, a senior said, “if you’re doing this change you need to start from the[your] year itself and then wait till the batches who were ****ed over previously pass.” While reflective of the frustrations students have endured over time, this sentiment is disheartening and not one that should be held by students of such a forward thinking, student centric, and esteemed institution.

We, as students, should realise that the issue isn’t the fact that the seniors are screwing us over, it is very clearly a problem of the system. A system that needs to be changed because it leads to students feeling disregarded and frustrated. Most students don’t get the courses they want. They end up having to beg the professor to enroll them into the class by getting special permission to increase class size, and even then, they may not get the course as timetable issues continue to rise as well.

The second year batch of B.Tech Mechanical Engineering continue to fight a losing battle as they email the admin about timetable changes to accommodate UWEs they wish to pursue (in demand by 40+ students in a batch of 75); however it has led to no real solutions. The final word from the admin is an email stating that the final timetable has been sent and no changes can be made.

Furthermore, students also don’t get seats for their major electives. Around half the students in the third year batch of B. Tech CSE are left without a major elective because of a lack of seats in the courses. I was informed that this has become common practice at this point and the seniors told them to finish their CCC requirements this year so that they can focus on the major electives in their fourth year.

The system also pits the students against each other by creating a situation where each batch gets to pick their courses one at a time, with the 4th years going first, the third years going second and so on. This systematically creates a divide between the students of different batches, as they feel like they aren’t treated fairly. It is understood that the system is in this state because the fourth year students need to be able to complete their degrees and their minors so they get the priority choices; however many fourth years aren’t satisfied with the system either. They face issues due to the timetables, UWEs with minimal seats, and even apparent refusal in many cases from the college to give a credit extension to students in order for them to meet their degree requirements.

All this considered, the system is also broken from a technical standpoint. Constant server crashes, pages hanging, and people getting unenrolled from courses have become the norm to the point where the seniors were surprised that their course registration went smoothly due to changes made by the admin this year. This is a significant step in the right direction, but problems still plagued the second-year students due to their larger batch size.

The Swayam system, in its current form, presents its own challenges as well. Many parents and students have expressed their disheartenment with the system, where they feel like they are being forced into opting for an online course despite having paid full tuition fees with the expectation of having offline classes taught by highly qualified professors at the institution. Swayam was meant as a supplementary platform to allow students to explore subjects that the college could not offer. However, it has evolved into something that cannot be expressed as anything but a crutch for the temporary shortfall in the college’s availability of courses, faculty, and seats in said courses. Although we sincerely appreciate the Swayam system for letting students experience courses beyond what our prestigious university can provide, the current system has to be reevaluated to uphold the incredibly high academic standards that the institution holds dear.

Furthermore, in a discussion in a parents’ group a parent speculates, “They[Their] sole focus is external optic to attack new students and funds”. This One message alone should show the level of frustration the parents are feeling on the behalf of their wards, even after only one year at this university. This isn’t due to a lack of belief in the university, but this frustration has been piling up in the minds of the parents due to the practical challenges that students face. As students and parents, we know that the university has the foundation to be a beacon of academic excellence, which is why we chose to be here. However, these challenges make it hard to leave that thought unwavering in the minds of parents and students.

All this to say, a flawed system like this needs to be amended urgently so that we, the students of such a prestigious institution, can fully spread our wings and make the most of the world-class resources this university so generously provides.

"""

# %%
prompt = prompt_template.format(
    context = SNUCONtext, 
    question="what is the problem and the reason for it give me structured answer with bullets and shi"
)


response = model.invoke(prompt)
print(response.content)
# Out:
# The problem is that many students cannot secure the required CCC, UWE, or major‑elective seats and are forced to take online Swayam courses.
# - **Low faculty‑to‑student ratio** – the growing enrolment outpaces the number of professors.
# - **Limited classroom capacity** – physical rooms restrict how many students can be accommodated.
# - **Technical failures** – enrollment portal crashes and timing glitches prevent successful registration.
# - **Priority batch system** – senior students pick first, leaving fewer seats for lower years.
#
# As a result, students miss essential courses, incur extra workload, and feel disadvantaged by the system.

# %%
with open("Untitled.txt", "r") as file:
    contentt = file.read()
    print(contentt)
# Out:
# The Project Gutenberg eBook of A broken blossom,  vol. 3 of 3
#
# This ebook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever. You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this ebook or online
# at www.gutenberg.org. If you are not located in the United States,
# you will have to check the laws of the country where you are located
# before using this eBook.
#
# Title: A broken blossom,  vol. 3 of 3
#
# Author: Florence Marryat
#
# Release date: September 1, 2025 [eBook #76781]
#
# Language: English
#
# Original publication: London: Samuel Tinsley & Co, 1879
#
# Credits: Richard Tonsing, Emmanuel Ackerman, and the Online Distributed Proofreading Team at https://www.pgdp.net (This book was produced from scanned images of public domain material from the Google Books project.)
#
#
# ...

# %%
'''with open("Job Description (65).pdf", "r") as file:
    contentt = file.read()
    print(contentt)'''
# Out:
# 'with open("Job Description (65).pdf", "r") as file:\n    contentt = file.read()\n    print(contentt)'

# %%
prompt = prompt_template.format(
    context = contentt[:len(contentt)//10],
    question="explain and summarise in under 5 lines, pretend i m 3 yrs old"
)
response = model.invoke(prompt)
print(response.content)
# Out:
# A girl named Hilda walks with her friend Charlie and they get into a little fight about love and who should help her with her money. She learns she needs to ask the right grown‑ups for help and hears about a fancy French baron and a pretty girl named Tessie. Feeling sorry, she writes a letter and decides to say sorry to Charlie.

# %%
newscon = """ China plans to accelerate the creation of a development bank and set up an international platform for energy cooperation, Chinese President Xi Jinping announced Monday at a summit that represents an emerging challenge to U.S. global leadership with the participation of Russia and India.

Russian President Vladimir Putin and Indian Prime Minister Narendra Modi were among the leaders meeting in Tianjin, in northern China, for the annual summit of the Shanghai Cooperation Organization. The security forum was originally seen as a foil to U.S. influence in Central Asia and has grown in size and influence over the years.

Xi is attempting to expand the scope of the SCO. He announced initial plans for a development bank run by the organization, introduced a cooperation platform for green and energy industries and pledged $1.4 billion in loans over the next three years to the organization’s members.

Xi also said he was opening the way for SCO member states to use China’s BeiDou satellite system, an alternative to the GPS system controlled by the U.S.

Putin expressed support for Xi’s initiatives, saying he believes the SCO “could take on the leading role in efforts to form a more just and equal system of global governance in the world.”

Laos joined the SCO as a partner, a designation short of full membership, Chinese Foreign Minister Wang Yi told reporters. The combined group of members and partners has reached 27, representing countries in Central and Southeast Asia, along with China, India, Russia, Iran and others.

China on message
Xi stressed countries should reject Cold War thinking, rival power blocs and bullying and instead protect the U.N.-centered international system. He called for a world order with multiple power centers and a more just and balanced global governance system.

“The shadows of Cold War mentality, bullying, are not dissipating, and there are new challenges that are increasing, not diminishing,” said Xi, who has consistently spoken against what he calls a Cold War mentality, which is his way of referring to the tough approach to China by the U.S.

“The world has entered a new period of tumultuous change and global governance has arrived at a new crossroads,″ he said.

Alfred Wu, a professor at the National University of Singapore’s Lee Kuan Yew School of Public Policy, explained that Xi is seeking “to provide an alternate world order, because the U.S.-led world order is very much in decline.”

Putin echoed those themes in his own address and expressed support for Xi’s proposal “to create a new, more effective and functional system of global governance.”

Founded in 2001, the SCO now includes Russia, Belarus, China, India, Iran, Kazakhstan, Kyrgyzstan, Pakistan, Tajikistan and Uzbekistan. Afghanistan and Mongolia are observer states, and 14 other countries, including several from the Middle East, serve as “dialogue partners.”

The summit comes days ahead of a military parade in Beijing marking the 80th anniversary of Japan’s World War II surrender.

Regional relationships
On Sunday, Xi met with Modi and the two leaders vowed to resolve differences surrounding a border dispute, which led to a freeze in relations in 2020.

Putin arrived for the summit Sunday and will attend the parade Wednesday. Modi will not stay for the parade.

North Korean leader Kim Jong Un, who did not attend the SCO summit, will be present for the military parade, along with the leader of Myanmar’s military government, Senior Gen. Min Aung Hlaing.

Putin spoke to Xi on Sunday, ahead of the bilateral talks the two were scheduled to hold Tuesday. He updated the Chinese leader on the Russia-U.S. talks on the Ukraine war which were held in Alaska last month.

Development policy has been a large part of the messaging in recent days. Putin, in an interview released Saturday by China’s news agency Xinhua, said Russia and China were jointly “against discriminatory sanctions” that hurt the socioeconomic development of the world at large.

Russia, alongside its Chinese partners, supports the reform of the International Monetary Fund and the World Bank, he said.

“It is essential to end the use of finance as an instrument of neocolonialism, which runs counter to the interests of the global majority,” Putin said.

Security is still key
While China is eager for the SCO to take a larger role on the global stage, it remains to be seen how effective the organization can be. Its focus in the past has been on propping up the security initiatives of its member states. China said it is effective in combating terrorism, separatism and extremism.

Those threats are what Beijing cited after it swept more than 1 million Uyghurs, Kazakhs and members of other largely Muslim minorities into camps, prisons, and other detention facilities in 2018.

“Their anti-terrorism exercises are more about countering threats to authoritarian regimes rather than countering terrorism in its own right,” said Derek Grossman, a professor of international relations at the University of Southern California.

Even if the SCO summit’s reach and influence is ultimately limited, one thing is clear, he said: “China is on a diplomatic uptick and the U.S. is self destructing.”

____

Associated Press writer Kanis Leung in Hong Kong contributed to this report.

HUIZHONG WU
Wu covers Chinese culture, society, and politics for The Associated Press, as well as the country’s growing overseas influence from Bangkok. She was previously based in Taiwan and China.
twitter



The Associated Press is an independent global news organization dedicated to factual reporting. Founded in 1846, AP today remains the most trusted source of fast, accurate, unbiased news in all formats and the essential provider of the technology and services vital to the news business. More than half the world’s population sees AP journalism every day.



facebook"""

# %%
prompt = prompt_template.format(
    context = newscon, 
    question="summerise the news like i am 10 years old with bullet points and shi"
)


response = model.invoke(prompt)
print(response.content)
# Out:
# - China’s leader Xi said the SCO will start its own development bank and a new energy‑cooperation group, promising $1.4 billion in loans.
# - Russia, India and other Asian countries met in Tianjin to talk about sharing power and using China’s BeiDou satellites instead of U.S. GPS.
# - The group wants a fairer world where countries work together, not fight like in a Cold War.
